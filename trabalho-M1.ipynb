# %% [markdown]
# # Trabalho M1: Introdução à Programação com Python

# %% [markdown]
# ### Instruções de entrega
#
# 1. Escreva sua resposta **na célula de código logo abaixo de cada questão**. Não apague os enunciados.
# 2. Antes de entregar, execute **todas** as células na ordem (`Runtime -> Run all` / `Kernel -> Restart & Run All`) e **salve o notebook com as saídas visíveis**.
# 3. Não use recursos que ainda não foram estudados em aula.
# 4. Todas as funções pedidas devem ter **docstring** e nomes de variáveis significativos.
# 5. Trabalho **individual**.
#
# ### Critérios de avaliação
#
# | Critério | Peso |
# |---|---|
# | O programa funciona e produz a saída esperada | 50% |
# | Uso correto dos conceitos exigidos pela questão (funções, condicionais, laços, tipos) | 30% |
# | Legibilidade: nomes claros, comentários/docstrings, saída bem formatada | 20% |
#
#
# > **Atenção:** código que não executa (erro de sintaxe) não recebe a pontuação de funcionamento.
# > Se você não conseguir terminar uma questão, entregue a parte que funciona e explique em um comentário o que faltou.
#
# ### Uso de assistentes de IA
#
# O uso de assistentes é permitido para **tirar dúvidas**, mas você deve ser capaz de explicar cada linha do
# seu código. Na última célula do notebook há uma **declaração de uso de IA que deve ser preenchida**.

# %% [markdown]
# ---
#
# ## Parte 1: Variáveis, expressões, tipos e strings (3,0 pontos)

# %% [markdown]
# ### Questão 1: Orçamento de viagem (1,0 ponto)
#
# Escreva um programa que calcule o custo de uma viagem de carro.
#
# O programa deve ler do usuário, usando `input`:
#
# - a distância da viagem, em km (`float`);
# - o consumo médio do carro, em km/litro (`float`);
# - o preço do litro do combustível, em reais (`float`);
# - o valor total dos pedágios, em reais (`float`);
# - o número de pessoas que dividirão a despesa (`int`).
#
# Em seguida o programa deve calcular e exibir:
#
# 1. a quantidade de litros necessária (distância dividida pelo consumo);
# 2. o custo do combustível;
# 3. o custo total (combustível + pedágios);
# 4. o custo por pessoa;
# 5. o tipo (`type`) das variáveis da distância e do número de pessoas.
#
# Todos os valores em reais devem ser exibidos com **2 casas decimais** (use `round` ou formatação de string).
#
# Exemplo:
#
# ```
# Distância da viagem (km): 450
# Consumo médio (km/l): 12.5
# Preço do litro (R$): 5.89
# Total de pedágios (R$): 32.40
# Número de pessoas: 3
#
# Litros necessários: 36.0
# Custo do combustível: R$ 212.04
# Custo total da viagem: R$ 244.44
# Custo por pessoa: R$ 81.48
# Tipo da distância: <class 'float'> | Tipo do número de pessoas: <class 'int'>
# ```

# %%
distancia_viagem = float(input("Distância da viagem (km): "))
consumo_medio = float(input("Consumo médio (km/l): "))
preco_litro = float(input("Preço do litro (R$): "))
pedagios = float(input("Total de pedágios (R$): "))
pessoas = int(input("Número de pessoas: "))

litros = distancia_viagem / consumo_medio
custo_combustivel = litros * preco_litro
custo_total = custo_combustivel + pedagios
custo_pessoa = custo_total / pessoas

print()
print(f"Litros necessarios: {litros}")
print(f"Custo do combustivel: R${custo_combustivel:.2f}")
print(f"Custo total da viagem: R${custo_total:.2f}")
print(f"Custo por pessoa: R${custo_pessoa:.2f}")

print(f"Tipo da distância: {type(distancia_viagem)} | Tipo do número de pessoas: {type(pessoas)}")
# Out:
# Distância da viagem (km): 450
# Consumo médio (km/l): 12.5
# Preço do litro (R$): 5.89
# Total de pedágios (R$): 32.40
# Número de pessoas: 3
#
# Litros necessarios: 36.0
# Custo do combustivel: R$212.04
# Custo total da viagem: R$244.44
# Custo por pessoa: R$81.48
# Tipo da distância: <class 'float'> | Tipo do número de pessoas: <class 'int'>

# %% [markdown]
# ### Questão 2: Crachá do estudante (1,0 ponto)
#
# Escreva um programa que leia o **primeiro nome** e o **sobrenome** do usuário (em duas chamadas separadas de
# `input`) e monte um crachá com as informações abaixo:
#
# 1. o nome completo (primeiro nome + espaço + sobrenome);
# 2. o nome completo em MAIÚSCULAS e em minúsculas;
# 3. o total de letras do nome completo, **sem contar o espaço**;
# 4. as iniciais em maiúsculo, separadas por ponto (por exemplo, `A.S.`);
# 5. um e-mail sugerido no formato `primeironome.sobrenome@edu.br`, todo em minúsculas;
# 6. uma linha decorativa de `=` com o mesmo comprimento do nome completo (use o operador `*` de strings);
# 7. uma verificação booleana: a letra `"a"` aparece no nome completo em minúsculas? (use o operador `in` e exiba o valor `True`/`False`).
#
# Exemplo:
#
# ```
# Primeiro nome: Ana
# Sobrenome: Silva
#
# =========
# Ana Silva
# ANA SILVA
# ana silva
# Total de letras: 8
# Iniciais: A.S.
# E-mail: ana.silva@edu.br
# Contém a letra 'a': True
# =========
# ```

# %%
nome = input("Nome: ")
sobrenome = input("Sobrenome: ")
print()

nome_completo = nome + " " + sobrenome
nome_completo_maiusc = nome_completo.upper()
nome_completo_minusc = nome_completo.lower()

total_letras = len(nome_completo)-1

iniciais = nome[0].upper() + "." + sobrenome[0].upper() + "."

email = nome.lower() + "." + sobrenome.lower() + "@edu.br"

A = "A" in nome_completo.upper()

linha = len(nome_completo) * "="

print(linha)
print(nome_completo)
print(nome_completo_maiusc)
print(nome_completo_minusc)
print(f"Total de letras: {total_letras}")
print(f"Iniciais: {iniciais}")
print(f"Email: {email}")
print(f"Contem a letra A: {A}")
print(linha)
# Out:
# Nome: Ana
# Sobrenome: Silva
#
# =========
# Ana Silva
# ANA SILVA
# ana silva
# Total de letras: 8
# Iniciais: A.S.
# Email: ana.silva@edu.br
# Contem a letra A: True
# =========

# %% [markdown]
# ### Questão 3: Distância entre dois pontos (1,0 ponto)
#
# Usando a instrução `import` e o módulo `math`, escreva um programa que:
#
# 1. leia as coordenadas de dois pontos do plano: `x1`, `y1`, `x2` e `y2` (todos `float`);
# 2. calcule `dx` e `dy` como as diferenças **em valor absoluto** entre as coordenadas;
# 3. calcule a distância entre os pontos com a fórmula abaixo:
#
# $$distancia = \sqrt{dx^2 + dy^2}$$
#
# 4. calcule a área do círculo que tem essa distância como raio;
# 5. exiba `dx`, `dy`, a distância e a área, todos arredondados para 2 casas decimais com `round`.
#
# Exemplo:
#
# ```
# x1: 1
# y1: 2
# x2: 4
# y2: 6
#
# dx = 3.0
# dy = 4.0
# Distância entre os pontos: 5.0
# Área do círculo de raio 5.0: 78.54
# ```

# %%
import math

x1 = float(input("x1: "))
x2 = float(input("x2: "))
y1 = float(input("y1: "))
y2 = float(input("y2: "))

dx = abs(x2 - x1)
dy = abs(y2 - y1)

distancia = math.sqrt(dx ** 2 + dy ** 2)

area_circulo = math.pi * distancia ** 2

print()
print(f"dx = {dx:.2f}")
print(f"dy = {dy:.2f}")
print(f"Distancia entre os pontos: {distancia:.2f}")
print(f"Área do círculo com raio {distancia:.2f}: {area_circulo:.2f}")
# Out:
# x1: 1
# x2: 4
# y1: 2
# y2: 6
#
# dx = 3.00
# dy = 4.00
# Distancia entre os pontos: 5.00
# Área do círculo com raio 5.00: 78.54

# %% [markdown]
# ---
#
# ## Parte 2: Funções, encapsulamento e generalização (3,0 pontos)

# %% [markdown]
# ### Questão 4: Encapsulamento e refatoração (1,0 ponto)
#
# O código abaixo calcula e exibe a média de três alunos. Ele **funciona**, mas repete a mesma lógica três vezes:
#
# ```python
# nota1 = 7.0
# nota2 = 5.5
# nota3 = 9.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Ana:", round(media, 2))
#
# nota1 = 4.0
# nota2 = 6.5
# nota3 = 5.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Bruno:", round(media, 2))
#
# nota1 = 9.5
# nota2 = 8.0
# nota3 = 10.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Carla:", round(media, 2))
# ```
#
# Sua tarefa:
#
# **(a)** **Encapsule** essa lógica em uma função chamada `exibir_media(nome, nota1, nota2, nota3)`, que calcula a
# média das três notas e exibe a mensagem no mesmo formato. A função deve ter uma **docstring** descrevendo o que
# ela faz e o que significa cada parâmetro.
#
# **(b)** Chame a função três vezes para reproduzir exatamente a mesma saída do código original.
#
# **(c)** Na célula de texto indicada, explique com suas palavras: o que é **encapsulamento**, o que é
# **refatoração**, e por que a versão com função é melhor que a original.
#
# Saída esperada:
#
# ```
# Média de Ana: 7.17
# Média de Bruno: 5.17
# Média de Carla: 9.17
# ```

# %%
def exibir_media(nome, nota1, nota2, nota3):
  '''
    Essa função calcula e exibe a média de três notas de um aluno.
    Parâmetros: nome do aluno, primeira nota do aluno, segunda nota e terceira.
  '''
  media = (nota1 + nota2 + nota3) / 3
  print(f"Média de {nome}: {media:.2f}")

exibir_media("Ana", 7, 5.5, 9)
exibir_media("Bruno", 4, 6.5, 5)
exibir_media("Carla", 9.5, 8, 10)
# Out:
# Média de Ana: 7.17
# Média de Bruno: 5.17
# Média de Carla: 9.17

# %% [markdown]
# **(c) Sua explicação sobre encapsulamento e refatoração:**
#
# _(Encapsulamento é colocar uma tarefa realizada várias vezes durante o código dentro de uma função. Refatoração é deixar o código mais organizado e fácil de usar sem alterar a tarefa dele. Usar funções deixa o código mais organizado e otimizado e menos repetitivo. Além disso, usar funções permite ter menos chances de ocorrer erros durante o código e, se tiver erros, será mais fácil de encontrá-los.)_

# %% [markdown]
# ### Questão 5: Generalização, parâmetros e variáveis locais (1,0 ponto)
#
# **(a)** Escreva uma função chamada `moldura(texto, caractere, largura)` que exibe um texto dentro de uma moldura.
# A função deve:
#
# - imprimir uma linha formada pela repetição de `caractere`, com a `largura` especificada;
# - imprimir o `texto` entre dois `caractere` (um no início e outro no fim da linha);
# - imprimir novamente a linha de fechamento.
#
# A função deve ter uma **docstring**. Note que ela **não retorna valor**, apenas exibe (retorna `None`).
#
# Exemplo:
#
# ```
# moldura("Trabalho 1", "*", 20)
# ```
#
# Saída:
#
# ```
# ********************
# * Trabalho 1
# ********************
# ```
#
# **(b)** Chame `moldura` **três vezes**, com textos, caracteres e larguras diferentes, mostrando que a função foi
# **generalizada** pelos parâmetros.

# %%
def moldura(texto, caractere, largura):
  '''
  Exibe um texto dentro de uma moldura formada pelo caractere informado.
  Parâmetros: texto que será exibido dentro da moldura, caractere usado para formar a moldura, quantidade de caracteres da linha da moldura.
  '''
  linha = caractere * largura
  print(linha)
  print(f"{caractere} {texto} {caractere}")
  print(linha)
  print()

moldura("Oie", "!", 10)
moldura("Tudo bem", "?", 20)
moldura("Tchau", "#", 30)
# Out:
# !!!!!!!!!!
# ! Oie !
# !!!!!!!!!!
#
# ????????????????????
# ? Tudo bem ?
# ????????????????????
#
# ##############################
# # Tchau #
# ##############################

# %% [markdown]
# ### Questão 6: Desenhando com `jupyturtle` (1,0 ponto)
#
# Não esqueça de baixar o módulo `jupyturtle` antes de resolver a questão.

# %% [markdown]
# **(a)** Escreva uma função chamada `poligono(lados, tamanho)` que desenhe um polígono regular com o número de lados e o comprimento de lado informados. A função deve ter docstring.
#
# **(b)** Escreva uma função chamada `flor(petalas, lados, tamanho)` que **reutilize** `poligono` para desenhar
# uma flor.
#
# **(c)** Faça três desenhos: um triângulo, um hexágono e uma flor.
#
# Exemplo:
#
# ```
# make_turtle()
# flor(8, 4, 30)
# ```

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Download realizado: " + str(local))
    return filename

download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Download realizado: jupyturtle.py

# %%
from jupyturtle import *

def poligono(lados, tamanho):
  '''
  Desenha um polígono regular com a quantidade de lados e o tamanho informados.
  Parâmetros: quantidade de lados do polígono, comprimento de cada lado do polígono.
  '''
  for i in range (lados):
    forward(tamanho)
    left(360/lados)

def flor(petalas, lados, tamanho):
  '''
  Desenha uma flor formada por polígonos regulares com a quantidade de pétalas e o tamanho informados.
  Parâmetros: quantidade de pétalas da flor, quantidade de lados de cada polígono, comprimento de cada lado dos polígonos.
  '''
  for i in range (petalas):
    poligono(lados, tamanho)
    left(360/petalas)

# %%
make_turtle()
poligono(3, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="180.0" y2="23.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="23.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
make_turtle()
poligono(6, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="210.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="40.4" x2="190.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="5.7" x2="150.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.7" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
make_turtle()
flor(9, 9, 20)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="170.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="75.0" x2="185.3" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.3" y1="62.1" x2="188.8" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.8" y1="42.4" x2="178.8" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="25.1" x2="160.0" y2="18.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="18.3" x2="141.2" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="25.1" x2="131.2" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.2" y1="42.4" x2="134.7" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.7" y1="62.1" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="165.3" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.3" y1="62.1" x2="168.8" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="42.4" x2="158.8" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.8" y1="25.1" x2="140.0" y2="18.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="18.3" x2="121.2" y2="25.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.2" y1="25.1" x2="111.2" y2="42.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.2" y1="42.4" x2="114.7" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.7" y1="62.1" x2="130.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="153.5" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.5" y1="55.3" x2="143.5" y2="38.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.5" y1="38.0" x2="124.7" y2="31.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.7" y1="31.1" x2="105.9" y2="38.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="105.9" y1="38.0" x2="95.9" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.9" y1="55.3" x2="99.4" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.4" y1="75.0" x2="114.7" y2="87.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.7" y1="87.9" x2="134.7" y2="87.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.7" y1="87.9" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="140.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="57.7" x2="121.2" y2="50.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.2" y1="50.8" x2="102.4" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.4" y1="57.7" x2="92.4" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.4" y1="75.0" x2="95.9" y2="94.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.9" y1="94.7" x2="111.2" y2="107.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.2" y1="107.6" x2="131.2" y2="107.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.2" y1="107.6" x2="146.5" y2="94.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.5" y1="94.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="131.2" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.2" y1="68.2" x2="112.4" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.4" y1="75.0" x2="102.4" y2="92.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.4" y1="92.3" x2="105.9" y2="112.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="105.9" y1="112.0" x2="121.2" y2="124.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.2" y1="124.9" x2="141.2" y2="124.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="124.9" x2="156.5" y2="112.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.5" y1="112.0" x2="160.0" y2="92.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="92.3" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="131.2" y2="81.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.2" y1="81.8" x2="121.2" y2="99.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.2" y1="99.2" x2="124.7" y2="118.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.7" y1="118.9" x2="140.0" y2="131.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="131.7" x2="160.0" y2="131.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="131.7" x2="175.3" y2="118.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.3" y1="118.9" x2="178.8" y2="99.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="99.2" x2="168.8" y2="81.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="81.8" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="140.0" y2="92.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="92.3" x2="143.5" y2="112.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.5" y1="112.0" x2="158.8" y2="124.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.8" y1="124.9" x2="178.8" y2="124.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="124.9" x2="194.1" y2="112.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.1" y1="112.0" x2="197.6" y2="92.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.6" y1="92.3" x2="187.6" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.6" y1="75.0" x2="168.8" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="68.2" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="153.5" y2="94.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.5" y1="94.7" x2="168.8" y2="107.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="107.6" x2="188.8" y2="107.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.8" y1="107.6" x2="204.1" y2="94.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.1" y1="94.7" x2="207.6" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.6" y1="75.0" x2="197.6" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.6" y1="57.7" x2="178.8" y2="50.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="50.8" x2="160.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="57.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="165.3" y2="87.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.3" y1="87.9" x2="185.3" y2="87.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.3" y1="87.9" x2="200.6" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.6" y1="75.0" x2="204.1" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.1" y1="55.3" x2="194.1" y2="38.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.1" y1="38.0" x2="175.3" y2="31.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.3" y1="31.1" x2="156.5" y2="38.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.5" y1="38.0" x2="146.5" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.5" y1="55.3" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ---
#
# ## Parte 3: Expressões booleanas e condicionais (2,0 pontos)

# %% [markdown]
# ### Questão 7: Funções booleanas e operadores lógicos (1,0 ponto)
#
# **(a)** Escreva uma função chamada `eh_bissexto(ano)` que **retorne** `True` se o ano for bissexto e `False` caso contrário. Use os operadores `%`, `and`, `or` e `not` em uma **única expressão booleana** no `return`
# (não use `if`).
#
# **(b)** Escreva uma função chamada `eh_triangulo(a, b, c)` que retorne `True` se três medidas podem formar um
# triângulo. A condição é que cada lado seja **positivo** e que cada lado seja **menor** que a soma dos outros dois.
#
# **(c)** Usando `for i in range(...)`, exiba para os anos de **1996 a 2005** se cada um é bissexto ou não.
#
# **(d)** Teste `eh_triangulo` com pelo menos três combinações diferentes, exibindo o resultado de cada teste.
#
# Exemplo:
#
# ```
# 1996 é bissexto? True
# 1997 é bissexto? False
# ...
# 2000 é bissexto? True
# ...
# eh_triangulo(3, 4, 5) -> True
# eh_triangulo(1, 2, 10) -> False
# eh_triangulo(-1, 4, 5) -> False
# ```

# %%
""" a """
def eh_bissexto(ano):
  return (ano % 4 == 0 and ano % 100 != 0) or ano % 400 == 0

""" b """
def eh_triangulo(a, b, c):
  return a > 0 and b > 0 and c > 0 and a < b + c and b < c + a and c < a + b

""" c """
for ano in range (1996, 2006):
  print(f"{ano} é bissexto? -> {eh_bissexto(ano)}")

print()

""" d """
print(f"É triangulo (3, 4, 5)? -> {eh_triangulo(3, 4, 5)}")
print(f"É triangulo (1, 2, 10)? -> {eh_triangulo(1, 2, 10)}")
print(f"É triangulo (-1, 4, 5)? -> {eh_triangulo(-1, 4, 5)}")
# Out:
# 1996 é bissexto? -> True
# 1997 é bissexto? -> False
# 1998 é bissexto? -> False
# 1999 é bissexto? -> False
# 2000 é bissexto? -> True
# 2001 é bissexto? -> False
# 2002 é bissexto? -> False
# 2003 é bissexto? -> False
# 2004 é bissexto? -> True
# 2005 é bissexto? -> False
#
# É triangulo (3, 4, 5)? -> True
# É triangulo (1, 2, 10)? -> False
# É triangulo (-1, 4, 5)? -> False

# %% [markdown]
# ### Questão 8: Condicionais encadeadas e aninhadas (1,0 ponto)
#
# Escreva uma função chamada `classificar_imc(peso, altura)` que:
#
# 1. **valide os dados**: se `peso` **ou** `altura` for menor ou igual a zero, a função deve
#    retornar `None`, sem calcular nada;
# 2. caso os dados sejam válidos, calcule o IMC com a fórmula `imc = peso / altura ** 2`;
# 3. use uma **condicional encadeada** (`if`/`elif`/`else`) para **retornar** a classificação correspondente:
#
# | IMC | Classificação |
# |---|---|
# | menor que 18,5 | `"Abaixo do peso"` |
# | de 18,5 a 24,9 | `"Peso normal"` |
# | de 25,0 a 29,9 | `"Sobrepeso"` |
# | 30,0 ou mais | `"Obesidade"` |
#
# Depois, escreva um programa que leia o peso e a altura do usuário, chame a função e:
#
# - se o retorno for `None`, exiba a mensagem `"Dados inválidos: peso e altura devem ser positivos."`;
# - caso contrário, exiba o IMC arredondado com 2 casas decimais e a classificação.
#
# A função deve ter **docstring**.
#
# Exemplo:
#
# ```
# Peso (kg): 72.5
# Altura (m): 1.75
# IMC: 23.67 -> Peso normal
# ```
#
# ```
# Peso (kg): 70
# Altura (m): 0
# Dados inválidos: peso e altura devem ser positivos.
# ```

# %%
def classificar_imc(peso, altura):
  '''
  Calcula e retorna o IMC usando o peso e a altura informados.
  Parâmetros: peso e altura do usuario.
  Retorna None se os valores forem inválidos.
  '''
  if (peso <= 0 or altura <= 0):
    return None
  else:
    imc = peso / altura ** 2
    return imc

peso = float(input("Peso (kg): "))
altura = float(input("Altura(m): "))

imc = classificar_imc(peso, altura)

if (imc == None):
  print("Dados inválidos: peso e altura devem ser positivos.")
elif (imc < 18.5):
  classificacao = "Abaixo do peso"
elif (imc >= 18.5 and imc <= 24.9):
  classificacao = "Peso normal"
elif (imc >= 25 and imc <= 29.9):
  classificacao = "Sobrepeso"
else:
  classificacao = "Obesidade"

if (imc != None):
  print(f"IMC: {imc:.2f} -> {classificacao}")
# Out:
# Peso (kg): 72.5
# Altura(m): 1.75
# IMC: 23.67 -> Peso normal

# %%
def classificar_imc(peso, altura):
  '''
  Calcula e retorna o IMC usando o peso e a altura informados.
  Parâmetros: peso e altura do usuario.
  Retorna None se os valores forem inválidos.
  '''
  if (peso <= 0 or altura <= 0):
    return None
  else:
    imc = peso / altura ** 2
    return imc

peso = float(input("Peso (kg): "))
altura = float(input("Altura(m): "))

imc = classificar_imc(peso, altura)

if (imc == None):
  print("Dados inválidos: peso e altura devem ser positivos.")
elif (imc < 18.5):
  classificacao = "Abaixo do peso"
elif (imc >= 18.5 and imc <= 24.9):
  classificacao = "Peso normal"
elif (imc >= 25 and imc <= 29.9):
  classificacao = "Acima do peso"
else:
  classificacao = "Obesidade"

if (imc != None):
  print(f"IMC: {imc:.2f} -> {classificacao}")
# Out:
# Peso (kg): 70
# Altura(m): 0
# Dados inválidos: peso e altura devem ser positivos.

# %% [markdown]
# ---
#
# ## Parte 4: Valores de retorno, `None` e docstrings (0,5 ponto)

# %% [markdown]
# ### Questão 9: `print` não é `return` (0,5 ponto)
#
# **(a)** Escreva duas funções, ambas com docstring:
#
# - `mostrar_dobro(numero)`: **exibe** o dobro do número com `print` e **não retorna nada**;
# - `calcular_dobro(numero)`: **retorna** o dobro do número, sem exibir nada.
#
# **(b)** Execute e observe os quatro comandos abaixo, mantendo as saídas visíveis:
#
# ```python
# mostrar_dobro(5)
# print(mostrar_dobro(5))
# calcular_dobro(5)
# print(calcular_dobro(5))
# ```
#
# **(c)** Mostre que o valor de retorno pode ser usado em uma expressão, por exemplo:
# `print(calcular_dobro(5) + calcular_dobro(10))`. Tente fazer o mesmo com `mostrar_dobro` e copie o erro em um
# comentário.
#
# **(d)** Na célula de texto indicada, responda:
#
# 1. Por que `print(mostrar_dobro(5))` exibe `None`?
# 2. Qual das duas funções é mais reaproveitável e por quê?
# 3. Para que serve uma **docstring** e em que ela se diferencia de um comentário comum? Cite um exemplo de ferramenta que **lê** a docstring das suas funções.

# %%
def mostrar_dobro(numero):
    '''
    Exibe o dobro de um número.
    '''
    print(numero * 2)


def calcular_dobro(numero):
    '''
    Retorna o dobro de um número.
    '''
    return numero * 2

mostrar_dobro(5)
print(mostrar_dobro(5))
calcular_dobro(5)
print(calcular_dobro(5))
# Out:
# 10
# 10
# None
# 10

# %%
print(calcular_dobro(5) + calcular_dobro(10))
# Out:
# 30

# %%
print(mostrar_dobro(5) + mostrar_dobro(10))

'''
10
20
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
/tmp/ipykernel_1274/1778646724.py in <cell line: 0>()
----> 1 print(mostrar_dobro(5) + mostrar_dobro(10))
      2

TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'
'''
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2872/1484457463.py in <cell line: 0>()
# ----> 1 print(mostrar_dobro(5) + mostrar_dobro(10))
#       2
#       3 '''
#       4 10
#       5 20
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %% [markdown]
# **(d) Suas respostas:**
#
# 1. _O motivo de print(mostrar_dobro(5)) mostrar None é porquê a função mostrar_dobro() não retorna nada por ser apenas um print, logo, não há nada para imprimnir. Então a saída é composta pelo print dentro da função (10) e pelo print externo (None)._
#
# 2. _A função mais reaproveitável é a def calcular_dobro(numero). Porque, além de ela mostrar o dobro, ela também o calcula e o armazena, caso precise utilizá-lo novamente._
#
# 3. _Uma docstring é uma string de documentação colocada no início de uma função, usada para explicar sua finalidade, seus parâmetros e retorno. Ela se diferencia de um comentário pois pode ser acessada pelo próprio Python e por certas ferramentas. Um comentário feito por # serve apenas para explicar o código e é ignorado durante a execução. Um exemplo de ferramenta que lê docstrings é o help()_.

# %% [markdown]
# ---
#
# ## Parte 5: Plano de desenvolvimento e desenvolvimento incremental (1,5 ponto)

# %% [markdown]
# ### Questão 10: Boletim da turma (1,5 ponto)
#
# Escreva um programa que gere o boletim de uma turma.
#
# O programa deve:
#
# 1. ler a quantidade de alunos (`int`);
# 2. para cada aluno:
#    - ler o nome (`str`) e três notas (`float`);
#    - calcular a média com uma função `media_notas(nota1, nota2, nota3)` que **retorna** o valor;
#    - obter a situação com uma função `situacao(media)` que **retorna** `"Aprovado"` (média maior ou igual a 7),
#      `"Recuperação"` (média maior ou igual a 4 e menor que 7) ou `"Reprovado"` (média menor que 4);
#    - exibir uma linha do boletim com o nome, a média (1 casa decimal) e a situação;
# 3. ao final, exibir:
#    - a média geral da turma (2 casas decimais);
#    - a quantidade e o **percentual** de aprovados;
#    - o nome do aluno com a maior média.
#
# Todas as funções devem ter **docstring**.
#
# Exemplo:
#
# ```
# Quantos alunos? 3
#
# Aluno 1 - nome: Ana
# Nota 1: 7
# Nota 2: 5.5
# Nota 3: 9
# Aluno 2 - nome: Bruno
# Nota 1: 4
# Nota 2: 3
# Nota 3: 2
# Aluno 3 - nome: Carla
# Nota 1: 9.5
# Nota 2: 8
# Nota 3: 10
#
# ===== BOLETIM =====
# Ana: 7.2 - Aprovado
# Bruno: 3.0 - Reprovado
# Carla: 9.2 - Aprovado
# ===================
# Média geral da turma: 6.44
# Aprovados: 2 de 3 (66.67%)
# Melhor média: Carla (9.17)
# ```
#
# **(a) Plano de desenvolvimento:** *antes* de programar, descreva na célula de
# texto abaixo o seu plano: quais funções você vai criar, quais parâmetros cada uma recebe, o que cada uma retorna e em que ordem você vai construir o programa.
#
# **(b) Desenvolvimento incremental:** escreva o programa em etapas, testando cada uma. Nas células de código indicadas, mantenha as **três versões**:
#
# - **Versão 1:** apenas as funções `media_notas` e `situacao`, testadas com valores fixos (sem `input`).
# - **Versão 2:** o laço que lê os alunos e exibe as linhas do boletim.
# - **Versão 3:** a versão final, com as estatísticas do final do boletim.
#
# **(c)** Ao final, comente na célula de texto o que mudou de uma versão para a outra e qual erro você encontrou (e corrigiu) durante o processo.

# %% [markdown]
# **(a) Seu plano de desenvolvimento:**
#
# _Primeiro, eu iria criar a função `media_notas`, que receberia as três notas e retornaria a média do aluno. Depois, faria a função `situacao_media`, que receberia a média e diria se o aluno foi aprovado, ficou de recuperação ou foi reprovado. Em seguida, faria o programa para receber vários alunos e guardar os nomes, médias e situações. Por último, criaria as funções para calcular a média da turma, contar e calcular a porcentagem de aprovados e encontrar o aluno com a maior média. Eu faria o programa aos poucos, testando cada parte antes de adicionar as próximas._

# %%
def media_notas(nota1, nota2, nota3):
  '''
  Calcula e retorna a média das três notas informadas.
  Parâmetros: nota1, nota2 e nota3 do aluno.
  Retorna a média das notas.
  '''
  return (nota1+nota2+nota3)/3

def situacao_media(media):
  '''
  Classifica e retorna a situação do aluno de acordo com a média informada.
  Parâmetro: média do aluno.
  Retorna Aprovado(a), Recuperação ou Reprovado(a).
  '''
  if (media >= 7):
    return "Aprovado(a)"
  elif (media >= 4):
    return "Recuperação"
  else:
    return "Reprovado(a)"

# Teste com valores fixos

print(media_notas(4, 7, 10))
print(situacao_media(3))
print(situacao_media(5))
print(situacao_media(8))
# Out:
# 7.0
# Reprovado(a)
# Recuperação
# Aprovado(a)

# %%
def media_notas(nota):
  '''
  Calcula e retorna a média das três notas informadas.
  Parâmetro: lista contendo as notas do aluno.
  Retorna a média das notas.
  '''
  soma = 0
  for i in range (3):
    soma += nota[i]
  return soma/3

def situacao_media(media):
  '''
  Classifica e retorna a situação do aluno de acordo com a média informada.
  Parâmetro: média do aluno.
  Retorna Aprovado(a), Recuperação ou Reprovado(a).
  '''
  if (media >= 7):
    return "Aprovado(a)"
  elif (media >= 4):
    return "Recuperação"
  else:
    return "Reprovado(a)"

n = int(input("Quantidade de alunos: "))

print()

nome = []
media = []
situacao = []

for i in range (n):
  nota = []
  nome.append(input(f"Nome do aluno {i+1}: "))
  print()
  for j in range (3):
    nota.append(float(input(f"Nota {j+1} de {nome[i]}: ")))
  print()
  media.append(media_notas(nota))
  situacao.append(situacao_media(media[i]))

print()
print("===== BOLETIM =====")
print()

for i in range (n):
  print(f"{nome[i]}: {media[i]:.1f} - {situacao[i]}")

print()
print("===================")
print()
# Out:
# Quantidade de alunos: 3
#
# Nome do aluno 1: Ana
#
# Nota 1 de Ana: 7
# Nota 2 de Ana: 5.5
# Nota 3 de Ana: 9
#
# Nome do aluno 2: Bruno
#
# Nota 1 de Bruno: 4
# Nota 2 de Bruno: 3
# Nota 3 de Bruno: 2
#
# Nome do aluno 3: Carla
#
# Nota 1 de Carla: 9.5
# Nota 2 de Carla: 8
# Nota 3 de Carla: 10
#
#
# ===== BOLETIM =====
#
# Ana: 7.2 - Aprovado(a)
# Bruno: 3.0 - Reprovado(a)
# Carla: 9.2 - Aprovado(a)
#
# ===================

# %%
def media_aluno(nota):
  '''
  Calcula e retorna a média das três notas informadas.
  Parâmetro: lista contendo as notas do aluno.
  Retorna a média das notas.
  '''
  soma = 0
  for i in range (3):
    soma += nota[i]
  return soma/3

def situacao_media(media):
  '''
  Classifica e retorna a situação do aluno de acordo com a média informada.
  Parâmetro: média do aluno.
  Retorna Aprovado(a), Recuperação ou Reprovado(a).
  '''
  if (media >= 7):
    return "Aprovado(a)"
  elif (media >= 4):
    return "Recuperação"
  else:
    return "Reprovado(a)"

def soma_medias(media, soma):
  '''
  Calcula e retorna a soma das médias dos alunos.
  Parâmetros: média do aluno e soma das médias anteriores.
  Retorna a soma atualizada das médias.
  '''
  soma += media
  return soma

def media_turma(soma, n):
  '''
  Calcula e retorna a média geral da turma.
  Parâmetros: soma das médias dos alunos e quantidade de alunos.
  Retorna a média geral da turma.
  '''
  return soma / n

def qntd_aprovados(situacao, aprovados):
  '''
  Calcula e retorna a quantidade de alunos aprovados.
  Parâmetros: situação do aluno e quantidade de aprovados anteriores.
  Retorna a quantidade atualizada de aprovados.
  '''
  if (situacao == "Aprovado(a)"):
    aprovados += 1
  return aprovados

def calcula_perc_aprovados(aprovados, n):
  '''
  Calcula e retorna a porcentagem de alunos aprovados.
  Parâmetros: quantidade de aprovados e quantidade total de alunos.
  Retorna a porcentagem de alunos aprovados.
  '''
  return (aprovados / n) * 100

n = int(input("Quantidade de alunos: "))

print()

nome = []
media = []
situacao = []
soma = 0
aprovados = 0

for i in range (n):

  nome.append(input(f"Nome do aluno {i+1}: "))

  print()

  nota = []

  for j in range (3):
    nota.append(float(input(f"Nota {j+1} de {nome[i]}: ")))

  print()

  media.append(media_aluno(nota))
  soma = soma_medias(media[i], soma)

  situacao.append(situacao_media(media[i]))
  aprovados = qntd_aprovados(situacao[i], aprovados)

media_geral = media_turma(soma, n)
perc_aprovados = calcula_perc_aprovados(aprovados, n)

maior_media = media[0]
aluno_maior_media = nome[0]

for i in range (1, n):
  if (media[i]>maior_media):
    maior_media = media[i]
    aluno_maior_media = nome[i]

print()
print("===== BOLETIM =====")
print()

for i in range (n):
  print(f"{nome[i]}: {media[i]:.1f} - {situacao[i]}")

print()
print("===================")
print()

print(f"Média geral da turma: {media_geral:.2f}")
print(f"Aprovados: {aprovados} de {n} ({perc_aprovados:.2f}%)")
print(f"Aluno com maior media: {aluno_maior_media} ({maior_media:.2f})")
# Out:
# Quantidade de alunos: 3
#
# Nome do aluno 1: Ana
#
# Nota 1 de Ana: 7
# Nota 2 de Ana: 5.5
# Nota 3 de Ana: 9
#
# Nome do aluno 2: Bruno
#
# Nota 1 de Bruno: 4
# Nota 2 de Bruno: 3
# Nota 3 de Bruno: 2
#
# Nome do aluno 3: Carla
#
# Nota 1 de Carla: 9.5
# Nota 2 de Carla: 8
# Nota 3 de Carla: 10
#
#
# ===== BOLETIM =====
#
# Ana: 7.2 - Aprovado(a)
# Bruno: 3.0 - Reprovado(a)
# Carla: 9.2 - Aprovado(a)
#
# ===================
#
# Média geral da turma: 6.44
# Aprovados: 2 de 3 (66.67%)
# Aluno com maior media: Carla (9.17)

# %% [markdown]
# **(c) O que mudou entre as versões e quais erros você corrigiu:**
#
# _O programa evoluiu em três versões. A primeira calculava a média e a situação de um aluno. Na segunda, ele passou a lidar com vários alunos, guardando nome, média e situação de cada um. A terceira adicionou cálculos mais complexos: média geral da turma, quantidade e porcentagem de aprovados, e identificação de quem teve a melhor nota. Cada versão acrescentou funcionalidades novas conforme as necessidades apareciam._

# %% [markdown]
# ---
#
# ## Declaração de uso de assistentes de IA
#
# Preencha honestamente:
#
# - **Usei assistente de IA neste trabalho?** ( ) Não  (X) Sim
# - **Em quais questões e para quê?** _Usei a IA na questão 10 para entender a lógica do exercício. Quando o código não funcionava ou apresentava erros, perguntava à IA o que tinha acontecido. Com as explicações, tentava identificar e corrigir os problemas sozinho. A IA funcionou como suporte enquanto eu aprendia._
# - **Declaro que sou capaz de explicar cada linha do código entregue:** (X) Sim
#
# ---
#
# **Happy Coding! 🐍**
